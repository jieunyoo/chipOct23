# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


df2 = pd.read_csv('voltages.csv')
df2
xdata0 = df2.to_numpy().flatten()
xdata2 = xdata0+100
xdata = xdata2/10
xdata
# Out:
# array([ 30.2,  30.4,  30.6, ..., 479.6, 479.8, 480. ])

# %%
df1 = pd.read_csv('bits.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

ydata0 = df1['1'].to_numpy().flatten()
ydata1 = df1['2'].to_numpy().flatten()
ydata2 = df1['3'].to_numpy().flatten()

plt.plot(xdata,ydata0, label='bit 1')
plt.plot(xdata,ydata1, label='bit 2')
plt.plot(xdata,ydata2, label='bit 3')
plt.legend(loc='upper right',framealpha=0.0)
plt.xlabel('voltage (mV)')
plt.ylabel('fraction of 0s')
#plt.title('bits 1,2,3')
plt.xlim([20,350])
#plt.savefig('Scurvebit012.png')
# Out:
# (20.0, 350.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

ydata0 = df1['0'].to_numpy().flatten()
ydata1 = df1['1'].to_numpy().flatten()
ydata2 = df1['2'].to_numpy().flatten()

plt.plot(xdata,ydata0, label='bit 0')
plt.plot(xdata,ydata1, label='bit 1')
plt.plot(xdata,ydata2, label='bit 2')
plt.legend(loc='upper right',framealpha=0.0)
plt.xlabel('voltage (mV)')
plt.ylabel('fraction of 0s')
#plt.title('bits 4,5,6')
plt.xlim([20,350])
#plt.savefig('Scurvebit345.png')
# Out:
# (20.0, 350.0)
